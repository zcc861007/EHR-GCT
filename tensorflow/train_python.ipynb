# %% [markdown]
# # Step-by-step to train the model
# * Clone the repository.
# * Request access to the eICU dataset from eICU website.
#   * Note that you are required to participate in the CITI training.
# * Download the patient, admissionDx, diagnosis, treatment CSV files.
# * Generate TFRecords using eicu_samples/process_eicu.py.
#   * `python process_eicu.py <path to CSV files> <output path>`
#   * By default, this will generate 5 randomly sampled sets of train/validation/test data.
# * Train model using train.py
#   * `python train.py <path to TFRecords> <output path>`.

# %%
proj_dir = '/content/drive/MyDrive/Courses/CS598-DL4H/project'

import os
print(os.path.exists(proj_dir))
# Out:
# True

# %% [markdown]
# # Model Training

# %%
py_file = os.path.join(proj_dir, 'train.py')
data_dir = os.path.join(proj_dir, 'eicu_samples/proc_data/fold_0')
out_dir = os.path.join(proj_dir, 'eicu_samples/results')
# print(os.path.exists(py_file))
# print(os.path.exists(data_dir))
# print(os.path.exists(out_dir))

# !python {py_file} {data_dir} {out_dir}
# Out:
# Streaming output truncated to the last 5000 lines.
# 2024-04-13 07:45:39.007780: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:45:39.008116: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:45:39.008344: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:45:39.008626: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:45:39.008822: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:45:39.008963: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13949 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# INFO:tensorflow:Restoring parameters from /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-56100
# I0413 07:45:39.009771 136811449708544 saver.py:1413] Restoring parameters from /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-56100
# INFO:tensorflow:Running local_init_op.
# I0413 07:45:39.139698 136811449708544 session_manager.py:545] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0413 07:45:39.162800 136811449708544 session_manager.py:548] Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# I0413 07:45:41.334893 136811449708544 evaluation.py:163] Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# I0413 07:45:41.465683 136811449708544 evaluation.py:163] Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# I0413 07:45:41.598262 136811449708544 evaluation.py:163] Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# I0413 07:45:41.737494 136811449708544 evaluation.py:163] Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# I0413 07:45:41.878879 136811449708544 evaluation.py:163] Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# I0413 07:45:41.999537 136811449708544 evaluation.py:163] Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# I0413 07:45:42.129833 136811449708544 evaluation.py:163] Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# I0413 07:45:42.251817 136811449708544 evaluation.py:163] Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# I0413 07:45:42.375703 136811449708544 evaluation.py:163] Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# I0413 07:45:42.507699 136811449708544 evaluation.py:163] Evaluation [100/100]
# INFO:tensorflow:Inference Time : 5.68337s
# I0413 07:45:44.595760 136811449708544 evaluation.py:269] Inference Time : 5.68337s
# INFO:tensorflow:Finished evaluation at 2024-04-13-07:45:44
# I0413 07:45:44.596084 136811449708544 evaluation.py:271] Finished evaluation at 2024-04-13-07:45:44
# INFO:tensorflow:Saving dict for global step 56100: AUC-PR = 0.2794133, AUC-ROC = 0.61916685, global_step = 56100, loss = 1.2513099
# I0413 07:45:44.596236 136811449708544 estimator.py:2085] Saving dict for global step 56100: AUC-PR = 0.2794133, AUC-ROC = 0.61916685, global_step = 56100, loss = 1.2513099
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 56100: /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-56100
# I0413 07:45:44.597045 136811449708544 estimator.py:2145] Saving 'checkpoint_path' summary for global step 56100: /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-56100
# INFO:tensorflow:global_step/sec: 11.1942
# I0413 07:45:44.620840 136811449708544 basic_session_run_hooks.py:716] global_step/sec: 11.1942
# INFO:tensorflow:loss = 0.13938567, step = 56100 (8.933 sec)
# I0413 07:45:44.621139 136811449708544 basic_session_run_hooks.py:263] loss = 0.13938567, step = 56100 (8.933 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 56200...
# I0413 07:45:46.651776 136811449708544 basic_session_run_hooks.py:627] Calling checkpoint listeners before saving checkpoint 56200...
# INFO:tensorflow:Saving checkpoints for 56200 into /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt.
# I0413 07:45:46.652027 136811449708544 basic_session_run_hooks.py:632] Saving checkpoints for 56200 into /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 56200...
# I0413 07:45:47.082964 136811449708544 basic_session_run_hooks.py:639] Calling checkpoint listeners after saving checkpoint 56200...
# INFO:tensorflow:Calling model_fn.
# I0413 07:45:47.153912 136811449708544 estimator.py:1175] Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# I0413 07:45:48.452746 136811449708544 estimator.py:1177] Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2024-04-13T07:45:48
# I0413 07:45:48.484280 136811449708544 evaluation.py:250] Starting evaluation at 2024-04-13T07:45:48
# INFO:tensorflow:Graph was finalized.
# I0413 07:45:48.640289 136811449708544 monitored_session.py:240] Graph was finalized.
# 2024-04-13 07:45:48.640951: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:45:48.641364: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:45:48.641640: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:45:48.641954: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:45:48.642242: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:45:48.642425: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13949 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# INFO:tensorflow:Restoring parameters from /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-56200
# I0413 07:45:48.643323 136811449708544 saver.py:1413] Restoring parameters from /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-56200
# INFO:tensorflow:Running local_init_op.
# I0413 07:45:48.831933 136811449708544 session_manager.py:545] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0413 07:45:48.855169 136811449708544 session_manager.py:548] Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# I0413 07:45:51.035187 136811449708544 evaluation.py:163] Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# I0413 07:45:51.183260 136811449708544 evaluation.py:163] Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# I0413 07:45:51.324117 136811449708544 evaluation.py:163] Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# I0413 07:45:51.452221 136811449708544 evaluation.py:163] Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# I0413 07:45:51.590357 136811449708544 evaluation.py:163] Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# I0413 07:45:51.718704 136811449708544 evaluation.py:163] Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# I0413 07:45:51.843689 136811449708544 evaluation.py:163] Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# I0413 07:45:51.974397 136811449708544 evaluation.py:163] Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# I0413 07:45:52.095029 136811449708544 evaluation.py:163] Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# I0413 07:45:52.229363 136811449708544 evaluation.py:163] Evaluation [100/100]
# INFO:tensorflow:Inference Time : 4.40007s
# I0413 07:45:52.884846 136811449708544 evaluation.py:269] Inference Time : 4.40007s
# INFO:tensorflow:Finished evaluation at 2024-04-13-07:45:52
# I0413 07:45:52.885230 136811449708544 evaluation.py:271] Finished evaluation at 2024-04-13-07:45:52
# INFO:tensorflow:Saving dict for global step 56200: AUC-PR = 0.28612325, AUC-ROC = 0.62236583, global_step = 56200, loss = 1.295384
# I0413 07:45:52.885410 136811449708544 estimator.py:2085] Saving dict for global step 56200: AUC-PR = 0.28612325, AUC-ROC = 0.62236583, global_step = 56200, loss = 1.295384
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 56200: /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-56200
# I0413 07:45:52.886029 136811449708544 estimator.py:2145] Saving 'checkpoint_path' summary for global step 56200: /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-56200
# INFO:tensorflow:global_step/sec: 12.0673
# I0413 07:45:52.907721 136811449708544 basic_session_run_hooks.py:716] global_step/sec: 12.0673
# INFO:tensorflow:loss = 0.18284807, step = 56200 (8.287 sec)
# I0413 07:45:52.907963 136811449708544 basic_session_run_hooks.py:263] loss = 0.18284807, step = 56200 (8.287 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 56300...
# I0413 07:45:54.552396 136811449708544 basic_session_run_hooks.py:627] Calling checkpoint listeners before saving checkpoint 56300...
# INFO:tensorflow:Saving checkpoints for 56300 into /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt.
# I0413 07:45:54.552625 136811449708544 basic_session_run_hooks.py:632] Saving checkpoints for 56300 into /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 56300...
# I0413 07:45:54.855126 136811449708544 basic_session_run_hooks.py:639] Calling checkpoint listeners after saving checkpoint 56300...
# INFO:tensorflow:Calling model_fn.
# I0413 07:45:54.901577 136811449708544 estimator.py:1175] Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# I0413 07:45:55.818521 136811449708544 estimator.py:1177] Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2024-04-13T07:45:55
# I0413 07:45:55.838420 136811449708544 evaluation.py:250] Starting evaluation at 2024-04-13T07:45:55
# INFO:tensorflow:Graph was finalized.
# I0413 07:45:55.934810 136811449708544 monitored_session.py:240] Graph was finalized.
# 2024-04-13 07:45:55.935358: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:45:55.935630: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:45:55.935796: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:45:55.936088: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:45:55.936286: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:45:55.936426: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13949 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# INFO:tensorflow:Restoring parameters from /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-56300
# I0413 07:45:55.936938 136811449708544 saver.py:1413] Restoring parameters from /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-56300
# INFO:tensorflow:Running local_init_op.
# I0413 07:45:56.055521 136811449708544 session_manager.py:545] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0413 07:45:56.077703 136811449708544 session_manager.py:548] Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# I0413 07:45:58.272362 136811449708544 evaluation.py:163] Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# I0413 07:45:58.417684 136811449708544 evaluation.py:163] Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# I0413 07:45:58.552532 136811449708544 evaluation.py:163] Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# I0413 07:45:58.681243 136811449708544 evaluation.py:163] Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# I0413 07:45:58.831681 136811449708544 evaluation.py:163] Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# I0413 07:45:59.036374 136811449708544 evaluation.py:163] Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# I0413 07:45:59.245596 136811449708544 evaluation.py:163] Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# I0413 07:45:59.472563 136811449708544 evaluation.py:163] Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# I0413 07:45:59.672677 136811449708544 evaluation.py:163] Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# I0413 07:45:59.880428 136811449708544 evaluation.py:163] Evaluation [100/100]
# INFO:tensorflow:Inference Time : 5.68128s
# I0413 07:46:01.519899 136811449708544 evaluation.py:269] Inference Time : 5.68128s
# INFO:tensorflow:Finished evaluation at 2024-04-13-07:46:01
# I0413 07:46:01.520296 136811449708544 evaluation.py:271] Finished evaluation at 2024-04-13-07:46:01
# INFO:tensorflow:Saving dict for global step 56300: AUC-PR = 0.28358987, AUC-ROC = 0.62779003, global_step = 56300, loss = 1.267781
# I0413 07:46:01.520520 136811449708544 estimator.py:2085] Saving dict for global step 56300: AUC-PR = 0.28358987, AUC-ROC = 0.62779003, global_step = 56300, loss = 1.267781
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 56300: /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-56300
# I0413 07:46:01.521264 136811449708544 estimator.py:2145] Saving 'checkpoint_path' summary for global step 56300: /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-56300
# INFO:tensorflow:global_step/sec: 11.5621
# I0413 07:46:01.556726 136811449708544 basic_session_run_hooks.py:716] global_step/sec: 11.5621
# INFO:tensorflow:loss = 0.18600234, step = 56300 (8.649 sec)
# I0413 07:46:01.557027 136811449708544 basic_session_run_hooks.py:263] loss = 0.18600234, step = 56300 (8.649 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 56400...
# I0413 07:46:03.261114 136811449708544 basic_session_run_hooks.py:627] Calling checkpoint listeners before saving checkpoint 56400...
# INFO:tensorflow:Saving checkpoints for 56400 into /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt.
# I0413 07:46:03.261358 136811449708544 basic_session_run_hooks.py:632] Saving checkpoints for 56400 into /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 56400...
# I0413 07:46:03.571260 136811449708544 basic_session_run_hooks.py:639] Calling checkpoint listeners after saving checkpoint 56400...
# INFO:tensorflow:Calling model_fn.
# I0413 07:46:03.618029 136811449708544 estimator.py:1175] Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# I0413 07:46:04.497930 136811449708544 estimator.py:1177] Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2024-04-13T07:46:04
# I0413 07:46:04.524298 136811449708544 evaluation.py:250] Starting evaluation at 2024-04-13T07:46:04
# INFO:tensorflow:Graph was finalized.
# I0413 07:46:04.624528 136811449708544 monitored_session.py:240] Graph was finalized.
# 2024-04-13 07:46:04.625084: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:46:04.625436: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:46:04.625621: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:46:04.625859: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:46:04.626070: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:46:04.626212: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13949 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# INFO:tensorflow:Restoring parameters from /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-56400
# I0413 07:46:04.627096 136811449708544 saver.py:1413] Restoring parameters from /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-56400
# INFO:tensorflow:Running local_init_op.
# I0413 07:46:04.760139 136811449708544 session_manager.py:545] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0413 07:46:04.784409 136811449708544 session_manager.py:548] Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# I0413 07:46:06.986168 136811449708544 evaluation.py:163] Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# I0413 07:46:07.120818 136811449708544 evaluation.py:163] Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# I0413 07:46:07.246701 136811449708544 evaluation.py:163] Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# I0413 07:46:07.378120 136811449708544 evaluation.py:163] Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# I0413 07:46:07.512949 136811449708544 evaluation.py:163] Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# I0413 07:46:07.646622 136811449708544 evaluation.py:163] Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# I0413 07:46:07.781110 136811449708544 evaluation.py:163] Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# I0413 07:46:07.904019 136811449708544 evaluation.py:163] Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# I0413 07:46:08.027741 136811449708544 evaluation.py:163] Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# I0413 07:46:08.154961 136811449708544 evaluation.py:163] Evaluation [100/100]
# INFO:tensorflow:Inference Time : 4.34758s
# I0413 07:46:08.872112 136811449708544 evaluation.py:269] Inference Time : 4.34758s
# INFO:tensorflow:Finished evaluation at 2024-04-13-07:46:08
# I0413 07:46:08.872402 136811449708544 evaluation.py:271] Finished evaluation at 2024-04-13-07:46:08
# INFO:tensorflow:Saving dict for global step 56400: AUC-PR = 0.2845547, AUC-ROC = 0.6186872, global_step = 56400, loss = 1.2786953
# I0413 07:46:08.872614 136811449708544 estimator.py:2085] Saving dict for global step 56400: AUC-PR = 0.2845547, AUC-ROC = 0.6186872, global_step = 56400, loss = 1.2786953
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 56400: /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-56400
# I0413 07:46:08.873335 136811449708544 estimator.py:2145] Saving 'checkpoint_path' summary for global step 56400: /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-56400
# INFO:tensorflow:global_step/sec: 13.6257
# I0413 07:46:08.895772 136811449708544 basic_session_run_hooks.py:716] global_step/sec: 13.6257
# INFO:tensorflow:loss = 0.1326732, step = 56400 (7.339 sec)
# I0413 07:46:08.896100 136811449708544 basic_session_run_hooks.py:263] loss = 0.1326732, step = 56400 (7.339 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 56500...
# I0413 07:46:10.557322 136811449708544 basic_session_run_hooks.py:627] Calling checkpoint listeners before saving checkpoint 56500...
# INFO:tensorflow:Saving checkpoints for 56500 into /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt.
# I0413 07:46:10.557551 136811449708544 basic_session_run_hooks.py:632] Saving checkpoints for 56500 into /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 56500...
# I0413 07:46:10.860113 136811449708544 basic_session_run_hooks.py:639] Calling checkpoint listeners after saving checkpoint 56500...
# INFO:tensorflow:Calling model_fn.
# I0413 07:46:10.907352 136811449708544 estimator.py:1175] Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# I0413 07:46:11.852270 136811449708544 estimator.py:1177] Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2024-04-13T07:46:11
# I0413 07:46:11.882917 136811449708544 evaluation.py:250] Starting evaluation at 2024-04-13T07:46:11
# INFO:tensorflow:Graph was finalized.
# I0413 07:46:12.015154 136811449708544 monitored_session.py:240] Graph was finalized.
# 2024-04-13 07:46:12.015737: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:46:12.016114: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:46:12.016343: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:46:12.016603: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:46:12.016811: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:46:12.016968: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13949 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# INFO:tensorflow:Restoring parameters from /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-56500
# I0413 07:46:12.017448 136811449708544 saver.py:1413] Restoring parameters from /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-56500
# INFO:tensorflow:Running local_init_op.
# I0413 07:46:12.207778 136811449708544 session_manager.py:545] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0413 07:46:12.242021 136811449708544 session_manager.py:548] Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# I0413 07:46:15.609118 136811449708544 evaluation.py:163] Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# I0413 07:46:15.740979 136811449708544 evaluation.py:163] Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# I0413 07:46:15.869785 136811449708544 evaluation.py:163] Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# I0413 07:46:16.015833 136811449708544 evaluation.py:163] Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# I0413 07:46:16.147332 136811449708544 evaluation.py:163] Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# I0413 07:46:16.274332 136811449708544 evaluation.py:163] Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# I0413 07:46:16.403547 136811449708544 evaluation.py:163] Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# I0413 07:46:16.529930 136811449708544 evaluation.py:163] Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# I0413 07:46:16.652562 136811449708544 evaluation.py:163] Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# I0413 07:46:16.802356 136811449708544 evaluation.py:163] Evaluation [100/100]
# INFO:tensorflow:Inference Time : 5.58643s
# I0413 07:46:17.469556 136811449708544 evaluation.py:269] Inference Time : 5.58643s
# INFO:tensorflow:Finished evaluation at 2024-04-13-07:46:17
# I0413 07:46:17.469821 136811449708544 evaluation.py:271] Finished evaluation at 2024-04-13-07:46:17
# INFO:tensorflow:Saving dict for global step 56500: AUC-PR = 0.29358476, AUC-ROC = 0.65103054, global_step = 56500, loss = 1.3945346
# I0413 07:46:17.469975 136811449708544 estimator.py:2085] Saving dict for global step 56500: AUC-PR = 0.29358476, AUC-ROC = 0.65103054, global_step = 56500, loss = 1.3945346
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 56500: /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-56500
# I0413 07:46:17.470707 136811449708544 estimator.py:2145] Saving 'checkpoint_path' summary for global step 56500: /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-56500
# INFO:tensorflow:global_step/sec: 11.6303
# I0413 07:46:17.493967 136811449708544 basic_session_run_hooks.py:716] global_step/sec: 11.6303
# INFO:tensorflow:loss = 0.2727283, step = 56500 (8.598 sec)
# I0413 07:46:17.494314 136811449708544 basic_session_run_hooks.py:263] loss = 0.2727283, step = 56500 (8.598 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 56600...
# I0413 07:46:19.109863 136811449708544 basic_session_run_hooks.py:627] Calling checkpoint listeners before saving checkpoint 56600...
# INFO:tensorflow:Saving checkpoints for 56600 into /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt.
# I0413 07:46:19.110107 136811449708544 basic_session_run_hooks.py:632] Saving checkpoints for 56600 into /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 56600...
# I0413 07:46:19.377585 136811449708544 basic_session_run_hooks.py:639] Calling checkpoint listeners after saving checkpoint 56600...
# INFO:tensorflow:Calling model_fn.
# I0413 07:46:19.431641 136811449708544 estimator.py:1175] Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# I0413 07:46:20.328945 136811449708544 estimator.py:1177] Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2024-04-13T07:46:20
# I0413 07:46:20.348878 136811449708544 evaluation.py:250] Starting evaluation at 2024-04-13T07:46:20
# INFO:tensorflow:Graph was finalized.
# I0413 07:46:20.447113 136811449708544 monitored_session.py:240] Graph was finalized.
# 2024-04-13 07:46:20.447681: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:46:20.448041: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:46:20.448241: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:46:20.448497: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:46:20.448685: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:46:20.448829: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13949 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# INFO:tensorflow:Restoring parameters from /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-56600
# I0413 07:46:20.449352 136811449708544 saver.py:1413] Restoring parameters from /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-56600
# INFO:tensorflow:Running local_init_op.
# I0413 07:46:20.570798 136811449708544 session_manager.py:545] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0413 07:46:20.592739 136811449708544 session_manager.py:548] Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# I0413 07:46:22.742165 136811449708544 evaluation.py:163] Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# I0413 07:46:22.876921 136811449708544 evaluation.py:163] Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# I0413 07:46:23.001683 136811449708544 evaluation.py:163] Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# I0413 07:46:23.147347 136811449708544 evaluation.py:163] Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# I0413 07:46:23.272163 136811449708544 evaluation.py:163] Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# I0413 07:46:23.394152 136811449708544 evaluation.py:163] Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# I0413 07:46:23.520524 136811449708544 evaluation.py:163] Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# I0413 07:46:23.641156 136811449708544 evaluation.py:163] Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# I0413 07:46:23.773936 136811449708544 evaluation.py:163] Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# I0413 07:46:23.893534 136811449708544 evaluation.py:163] Evaluation [100/100]
# INFO:tensorflow:Inference Time : 4.21470s
# I0413 07:46:24.563778 136811449708544 evaluation.py:269] Inference Time : 4.21470s
# INFO:tensorflow:Finished evaluation at 2024-04-13-07:46:24
# I0413 07:46:24.564096 136811449708544 evaluation.py:271] Finished evaluation at 2024-04-13-07:46:24
# INFO:tensorflow:Saving dict for global step 56600: AUC-PR = 0.29673713, AUC-ROC = 0.65291226, global_step = 56600, loss = 1.4920099
# I0413 07:46:24.564248 136811449708544 estimator.py:2085] Saving dict for global step 56600: AUC-PR = 0.29673713, AUC-ROC = 0.65291226, global_step = 56600, loss = 1.4920099
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 56600: /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-56600
# I0413 07:46:24.564898 136811449708544 estimator.py:2145] Saving 'checkpoint_path' summary for global step 56600: /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-56600
# INFO:tensorflow:global_step/sec: 14.0978
# I0413 07:46:24.587329 136811449708544 basic_session_run_hooks.py:716] global_step/sec: 14.0978
# INFO:tensorflow:loss = 0.29587114, step = 56600 (7.093 sec)
# I0413 07:46:24.587608 136811449708544 basic_session_run_hooks.py:263] loss = 0.29587114, step = 56600 (7.093 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 56700...
# I0413 07:46:26.625278 136811449708544 basic_session_run_hooks.py:627] Calling checkpoint listeners before saving checkpoint 56700...
# INFO:tensorflow:Saving checkpoints for 56700 into /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt.
# I0413 07:46:26.625517 136811449708544 basic_session_run_hooks.py:632] Saving checkpoints for 56700 into /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 56700...
# I0413 07:46:27.075658 136811449708544 basic_session_run_hooks.py:639] Calling checkpoint listeners after saving checkpoint 56700...
# INFO:tensorflow:Calling model_fn.
# I0413 07:46:27.140066 136811449708544 estimator.py:1175] Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# I0413 07:46:28.424960 136811449708544 estimator.py:1177] Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2024-04-13T07:46:28
# I0413 07:46:28.456839 136811449708544 evaluation.py:250] Starting evaluation at 2024-04-13T07:46:28
# INFO:tensorflow:Graph was finalized.
# I0413 07:46:28.597163 136811449708544 monitored_session.py:240] Graph was finalized.
# 2024-04-13 07:46:28.597741: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:46:28.598098: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:46:28.598299: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:46:28.598558: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:46:28.598747: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:46:28.598895: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13949 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# INFO:tensorflow:Restoring parameters from /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-56700
# I0413 07:46:28.599445 136811449708544 saver.py:1413] Restoring parameters from /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-56700
# INFO:tensorflow:Running local_init_op.
# I0413 07:46:28.724159 136811449708544 session_manager.py:545] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0413 07:46:28.746051 136811449708544 session_manager.py:548] Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# I0413 07:46:30.910063 136811449708544 evaluation.py:163] Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# I0413 07:46:31.043288 136811449708544 evaluation.py:163] Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# I0413 07:46:31.175943 136811449708544 evaluation.py:163] Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# I0413 07:46:31.308972 136811449708544 evaluation.py:163] Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# I0413 07:46:31.437786 136811449708544 evaluation.py:163] Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# I0413 07:46:31.578888 136811449708544 evaluation.py:163] Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# I0413 07:46:31.704455 136811449708544 evaluation.py:163] Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# I0413 07:46:31.827637 136811449708544 evaluation.py:163] Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# I0413 07:46:31.954431 136811449708544 evaluation.py:163] Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# I0413 07:46:32.077787 136811449708544 evaluation.py:163] Evaluation [100/100]
# INFO:tensorflow:Inference Time : 4.29440s
# I0413 07:46:32.751461 136811449708544 evaluation.py:269] Inference Time : 4.29440s
# INFO:tensorflow:Finished evaluation at 2024-04-13-07:46:32
# I0413 07:46:32.751754 136811449708544 evaluation.py:271] Finished evaluation at 2024-04-13-07:46:32
# INFO:tensorflow:Saving dict for global step 56700: AUC-PR = 0.31806803, AUC-ROC = 0.66043675, global_step = 56700, loss = 1.126274
# I0413 07:46:32.751914 136811449708544 estimator.py:2085] Saving dict for global step 56700: AUC-PR = 0.31806803, AUC-ROC = 0.66043675, global_step = 56700, loss = 1.126274
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 56700: /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-56700
# I0413 07:46:32.752676 136811449708544 estimator.py:2145] Saving 'checkpoint_path' summary for global step 56700: /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-56700
# INFO:tensorflow:global_step/sec: 12.2143
# I0413 07:46:32.774394 136811449708544 basic_session_run_hooks.py:716] global_step/sec: 12.2143
# INFO:tensorflow:loss = 0.22153606, step = 56700 (8.187 sec)
# I0413 07:46:32.774777 136811449708544 basic_session_run_hooks.py:263] loss = 0.22153606, step = 56700 (8.187 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 56800...
# I0413 07:46:34.390125 136811449708544 basic_session_run_hooks.py:627] Calling checkpoint listeners before saving checkpoint 56800...
# INFO:tensorflow:Saving checkpoints for 56800 into /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt.
# I0413 07:46:34.390357 136811449708544 basic_session_run_hooks.py:632] Saving checkpoints for 56800 into /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 56800...
# I0413 07:46:34.707467 136811449708544 basic_session_run_hooks.py:639] Calling checkpoint listeners after saving checkpoint 56800...
# INFO:tensorflow:Calling model_fn.
# I0413 07:46:34.755524 136811449708544 estimator.py:1175] Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# I0413 07:46:35.988867 136811449708544 estimator.py:1177] Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2024-04-13T07:46:36
# I0413 07:46:36.009397 136811449708544 evaluation.py:250] Starting evaluation at 2024-04-13T07:46:36
# INFO:tensorflow:Graph was finalized.
# I0413 07:46:36.104613 136811449708544 monitored_session.py:240] Graph was finalized.
# 2024-04-13 07:46:36.105296: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:46:36.105628: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:46:36.105813: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:46:36.106080: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:46:36.106285: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:46:36.106429: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13949 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# INFO:tensorflow:Restoring parameters from /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-56800
# I0413 07:46:36.107171 136811449708544 saver.py:1413] Restoring parameters from /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-56800
# INFO:tensorflow:Running local_init_op.
# I0413 07:46:36.239469 136811449708544 session_manager.py:545] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0413 07:46:36.262542 136811449708544 session_manager.py:548] Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# I0413 07:46:38.453433 136811449708544 evaluation.py:163] Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# I0413 07:46:38.595105 136811449708544 evaluation.py:163] Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# I0413 07:46:38.827414 136811449708544 evaluation.py:163] Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# I0413 07:46:39.027717 136811449708544 evaluation.py:163] Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# I0413 07:46:39.234656 136811449708544 evaluation.py:163] Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# I0413 07:46:39.432712 136811449708544 evaluation.py:163] Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# I0413 07:46:39.643938 136811449708544 evaluation.py:163] Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# I0413 07:46:39.868766 136811449708544 evaluation.py:163] Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# I0413 07:46:40.085764 136811449708544 evaluation.py:163] Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# I0413 07:46:40.278842 136811449708544 evaluation.py:163] Evaluation [100/100]
# INFO:tensorflow:Inference Time : 5.42250s
# I0413 07:46:41.432115 136811449708544 evaluation.py:269] Inference Time : 5.42250s
# INFO:tensorflow:Finished evaluation at 2024-04-13-07:46:41
# I0413 07:46:41.432577 136811449708544 evaluation.py:271] Finished evaluation at 2024-04-13-07:46:41
# INFO:tensorflow:Saving dict for global step 56800: AUC-PR = 0.31291136, AUC-ROC = 0.65443116, global_step = 56800, loss = 1.1829233
# I0413 07:46:41.432796 136811449708544 estimator.py:2085] Saving dict for global step 56800: AUC-PR = 0.31291136, AUC-ROC = 0.65443116, global_step = 56800, loss = 1.1829233
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 56800: /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-56800
# I0413 07:46:41.433804 136811449708544 estimator.py:2145] Saving 'checkpoint_path' summary for global step 56800: /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-56800
# INFO:tensorflow:global_step/sec: 11.5082
# I0413 07:46:41.463882 136811449708544 basic_session_run_hooks.py:716] global_step/sec: 11.5082
# INFO:tensorflow:loss = 0.25344077, step = 56800 (8.689 sec)
# I0413 07:46:41.464192 136811449708544 basic_session_run_hooks.py:263] loss = 0.25344077, step = 56800 (8.689 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 56900...
# I0413 07:46:43.279675 136811449708544 basic_session_run_hooks.py:627] Calling checkpoint listeners before saving checkpoint 56900...
# ...
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 64500...
# I0413 07:57:21.788398 136811449708544 basic_session_run_hooks.py:627] Calling checkpoint listeners before saving checkpoint 64500...
# INFO:tensorflow:Saving checkpoints for 64500 into /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt.
# I0413 07:57:21.788655 136811449708544 basic_session_run_hooks.py:632] Saving checkpoints for 64500 into /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 64500...
# I0413 07:57:22.226347 136811449708544 basic_session_run_hooks.py:639] Calling checkpoint listeners after saving checkpoint 64500...
# INFO:tensorflow:Calling model_fn.
# I0413 07:57:22.295965 136811449708544 estimator.py:1175] Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# I0413 07:57:23.226947 136811449708544 estimator.py:1177] Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2024-04-13T07:57:23
# I0413 07:57:23.247419 136811449708544 evaluation.py:250] Starting evaluation at 2024-04-13T07:57:23
# INFO:tensorflow:Graph was finalized.
# I0413 07:57:23.342689 136811449708544 monitored_session.py:240] Graph was finalized.
# 2024-04-13 07:57:23.343286: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:57:23.343604: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:57:23.343824: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:57:23.344120: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:57:23.344343: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:57:23.344487: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13949 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# INFO:tensorflow:Restoring parameters from /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-64500
# I0413 07:57:23.345373 136811449708544 saver.py:1413] Restoring parameters from /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-64500
# INFO:tensorflow:Running local_init_op.
# I0413 07:57:23.474448 136811449708544 session_manager.py:545] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0413 07:57:23.502533 136811449708544 session_manager.py:548] Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# I0413 07:57:25.670557 136811449708544 evaluation.py:163] Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# I0413 07:57:25.819865 136811449708544 evaluation.py:163] Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# I0413 07:57:25.949726 136811449708544 evaluation.py:163] Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# I0413 07:57:26.082636 136811449708544 evaluation.py:163] Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# I0413 07:57:26.206625 136811449708544 evaluation.py:163] Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# I0413 07:57:26.331400 136811449708544 evaluation.py:163] Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# I0413 07:57:26.463763 136811449708544 evaluation.py:163] Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# I0413 07:57:26.588970 136811449708544 evaluation.py:163] Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# I0413 07:57:26.717549 136811449708544 evaluation.py:163] Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# I0413 07:57:26.850427 136811449708544 evaluation.py:163] Evaluation [100/100]
# INFO:tensorflow:Inference Time : 4.26292s
# I0413 07:57:27.510521 136811449708544 evaluation.py:269] Inference Time : 4.26292s
# INFO:tensorflow:Finished evaluation at 2024-04-13-07:57:27
# I0413 07:57:27.510848 136811449708544 evaluation.py:271] Finished evaluation at 2024-04-13-07:57:27
# INFO:tensorflow:Saving dict for global step 64500: AUC-PR = 0.31518367, AUC-ROC = 0.6512464, global_step = 64500, loss = 1.2241493
# I0413 07:57:27.511040 136811449708544 estimator.py:2085] Saving dict for global step 64500: AUC-PR = 0.31518367, AUC-ROC = 0.6512464, global_step = 64500, loss = 1.2241493
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 64500: /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-64500
# I0413 07:57:27.511725 136811449708544 estimator.py:2145] Saving 'checkpoint_path' summary for global step 64500: /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-64500
# INFO:tensorflow:global_step/sec: 11.8601
# I0413 07:57:27.534745 136811449708544 basic_session_run_hooks.py:716] global_step/sec: 11.8601
# INFO:tensorflow:loss = 0.28415254, step = 64500 (8.432 sec)
# I0413 07:57:27.535035 136811449708544 basic_session_run_hooks.py:263] loss = 0.28415254, step = 64500 (8.432 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 64600...
# I0413 07:57:29.197519 136811449708544 basic_session_run_hooks.py:627] Calling checkpoint listeners before saving checkpoint 64600...
# INFO:tensorflow:Saving checkpoints for 64600 into /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt.
# I0413 07:57:29.197770 136811449708544 basic_session_run_hooks.py:632] Saving checkpoints for 64600 into /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 64600...
# I0413 07:57:29.471315 136811449708544 basic_session_run_hooks.py:639] Calling checkpoint listeners after saving checkpoint 64600...
# INFO:tensorflow:Calling model_fn.
# I0413 07:57:29.530684 136811449708544 estimator.py:1175] Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# I0413 07:57:30.442640 136811449708544 estimator.py:1177] Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2024-04-13T07:57:30
# I0413 07:57:30.463077 136811449708544 evaluation.py:250] Starting evaluation at 2024-04-13T07:57:30
# INFO:tensorflow:Graph was finalized.
# I0413 07:57:30.560816 136811449708544 monitored_session.py:240] Graph was finalized.
# 2024-04-13 07:57:30.561367: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:57:30.561672: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:57:30.561856: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:57:30.562132: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:57:30.562331: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:57:30.562485: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13949 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# INFO:tensorflow:Restoring parameters from /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-64600
# I0413 07:57:30.563043 136811449708544 saver.py:1413] Restoring parameters from /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-64600
# INFO:tensorflow:Running local_init_op.
# I0413 07:57:30.685247 136811449708544 session_manager.py:545] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0413 07:57:30.714528 136811449708544 session_manager.py:548] Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# I0413 07:57:33.246374 136811449708544 evaluation.py:163] Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# I0413 07:57:33.451556 136811449708544 evaluation.py:163] Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# I0413 07:57:33.681192 136811449708544 evaluation.py:163] Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# I0413 07:57:33.901196 136811449708544 evaluation.py:163] Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# I0413 07:57:34.132165 136811449708544 evaluation.py:163] Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# I0413 07:57:34.328882 136811449708544 evaluation.py:163] Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# I0413 07:57:34.550134 136811449708544 evaluation.py:163] Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# I0413 07:57:34.752402 136811449708544 evaluation.py:163] Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# I0413 07:57:34.965615 136811449708544 evaluation.py:163] Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# I0413 07:57:35.185306 136811449708544 evaluation.py:163] Evaluation [100/100]
# INFO:tensorflow:Inference Time : 5.67866s
# I0413 07:57:36.141941 136811449708544 evaluation.py:269] Inference Time : 5.67866s
# INFO:tensorflow:Finished evaluation at 2024-04-13-07:57:36
# I0413 07:57:36.142208 136811449708544 evaluation.py:271] Finished evaluation at 2024-04-13-07:57:36
# INFO:tensorflow:Saving dict for global step 64600: AUC-PR = 0.28570023, AUC-ROC = 0.6184887, global_step = 64600, loss = 1.2919335
# I0413 07:57:36.142358 136811449708544 estimator.py:2085] Saving dict for global step 64600: AUC-PR = 0.28570023, AUC-ROC = 0.6184887, global_step = 64600, loss = 1.2919335
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 64600: /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-64600
# I0413 07:57:36.143041 136811449708544 estimator.py:2145] Saving 'checkpoint_path' summary for global step 64600: /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-64600
# INFO:tensorflow:global_step/sec: 11.5848
# I0413 07:57:36.166713 136811449708544 basic_session_run_hooks.py:716] global_step/sec: 11.5848
# INFO:tensorflow:loss = 0.1283338, step = 64600 (8.632 sec)
# I0413 07:57:36.166974 136811449708544 basic_session_run_hooks.py:263] loss = 0.1283338, step = 64600 (8.632 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 64700...
# I0413 07:57:37.875810 136811449708544 basic_session_run_hooks.py:627] Calling checkpoint listeners before saving checkpoint 64700...
# INFO:tensorflow:Saving checkpoints for 64700 into /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt.
# I0413 07:57:37.876074 136811449708544 basic_session_run_hooks.py:632] Saving checkpoints for 64700 into /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 64700...
# I0413 07:57:38.185760 136811449708544 basic_session_run_hooks.py:639] Calling checkpoint listeners after saving checkpoint 64700...
# INFO:tensorflow:Calling model_fn.
# I0413 07:57:38.232569 136811449708544 estimator.py:1175] Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# I0413 07:57:39.120185 136811449708544 estimator.py:1177] Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2024-04-13T07:57:39
# I0413 07:57:39.139611 136811449708544 evaluation.py:250] Starting evaluation at 2024-04-13T07:57:39
# INFO:tensorflow:Graph was finalized.
# I0413 07:57:39.244555 136811449708544 monitored_session.py:240] Graph was finalized.
# 2024-04-13 07:57:39.245110: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:57:39.245458: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:57:39.245656: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:57:39.245901: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:57:39.246141: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-13 07:57:39.246307: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13949 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# INFO:tensorflow:Restoring parameters from /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-64700
# I0413 07:57:39.246810 136811449708544 saver.py:1413] Restoring parameters from /content/drive/MyDrive/Courses/CS598-DL4H/project/eicu_samples/results/model.ckpt-64700
# INFO:tensorflow:Running local_init_op.
# I0413 07:57:39.370846 136811449708544 session_manager.py:545] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0413 07:57:39.394176 136811449708544 session_manager.py:548] Done running local_init_op.
